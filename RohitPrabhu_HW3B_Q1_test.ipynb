# %%
from transformers import BertTokenizerFast
import pandas as pd
from nltk.corpus import words
import nltk
from transformers import BertTokenizer
from nltk.corpus import words, wordnet
import ast

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\findi\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
# Load English words from NLTK
nltk_words = set(words.words())

# Extract additional words from WordNet
wordnet_words = set(lemma.name().replace('_', ' ') for synset in wordnet.all_synsets() for lemma in synset.lemmas())

# Combine both word sets
english_vocab = nltk_words.union(wordnet_words)

# Load BERT tokenizer
tokenizer = BertTokenizerFast.from_pretrained("bert-base-uncased", do_lower_case=True)

# Identify missing words
missing_words = [word for word in english_vocab if tokenizer.tokenize(word) == ['[UNK]']]

print(f"Total Missing Words: {len(missing_words)}")
# Out:
# Total Missing Words: 0

# %%
df = pd.read_csv("subsetOfDataSoftware.csv")

# %%
def combine_subwords(tokens):
    """
    Combines subword tokens marked with '##' into complete words.
    
    Args:
    tokens (list): List of tokenized words from a tokenizer.

    Returns:
    list: List of cleaned words without subword fragmentation.
    """
    combined_tokens = []
    current_word = ""

    for token in tokens:
        if token.startswith("##"):
            # Append to the previous word (removing the '##')
            current_word += token[2:]
        else:
            # Add the previous complete word to the list if it exists
            if current_word:
                combined_tokens.append(current_word)
            # Start a new word
            current_word = token
        
    # Append the last word
    if current_word:
        combined_tokens.append(current_word)

    return combined_tokens

# %%
tokenized_text = {
    "id": [],
    "sentence": [],
    "length": []
}

# %%
id = 0
for d in df['description'].values:
    combined_txt = combine_subwords(tokenizer.tokenize(d))
    tokenized_text['id'].append(id)
    tokenized_text['sentence'].append(combined_txt)
    tokenized_text['length'].append(len((combined_txt)))
    id+=1
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (812 > 512). Running this sequence through the model will result in indexing errors

# %%
df_dict = pd.DataFrame(tokenized_text)

# %%
df_dict
# Out:
#         id                                           sentence  length
# 0        0  [education, bachelor, ', s, degree, in, softwa...      30
# 1        1  [job, description, :, goyt, is, seeking, a, sk...     295
# 2        2  [are, you, driven, by, the, thrill, of, solvin...     234
# 3        3  [request, :, data, architectlocation, :, san, ...      73
# 4        4  [this, opportunity, is, joining, an, innovatio...     252
# ...    ...                                                ...     ...
# 4621  4621  [we, ’, re, looking, for, people, who, put, th...     735
# 4622  4622  [role, title, :, data, engineering, lead, for,...     613
# 4623  4623  [overview, the, credit, risk, &, decision, sci...     913
# 4624  4624  [date, posted, :, 04, /, 19, /, 2024hiring, or...     570
# 4625  4625  [about, pinterest, :, millions, of, people, ac...     953
#
# [4626 rows x 3 columns]

# %%
import matplotlib.pyplot as plt
lengths = df_dict['length']
plt.figure(figsize=(8, 6));
plt.hist(lengths, bins=30, edgecolor='black');
plt.title('Histogram of Tokenized Sentence Lengths');
plt.xlabel('Sentence Length');
plt.ylabel('Frequency');
plt.grid(True);
plt.show();

# %%
subset=df_dict[df_dict['length'] < 900]

# %%
subset
# Out:
#         id                                           sentence  length
# 0        0  [education, bachelor, ', s, degree, in, softwa...      30
# 1        1  [job, description, :, goyt, is, seeking, a, sk...     295
# 2        2  [are, you, driven, by, the, thrill, of, solvin...     234
# 3        3  [request, :, data, architectlocation, :, san, ...      73
# 4        4  [this, opportunity, is, joining, an, innovatio...     252
# ...    ...                                                ...     ...
# 4619  4619  [about, this, featured, opportunity, we, are, ...     559
# 4620  4620  [exciting, long, -, term, and, fully, remote, ...     179
# 4621  4621  [we, ’, re, looking, for, people, who, put, th...     735
# 4622  4622  [role, title, :, data, engineering, lead, for,...     613
# 4624  4624  [date, posted, :, 04, /, 19, /, 2024hiring, or...     570
#
# [3346 rows x 3 columns]

# %%
max_length_row = subset[subset['length'] == subset['length'].max()]

# %%
max_length_row.iloc[0][0]
# Out:
# C:\Users\findi\AppData\Local\Temp\ipykernel_93216\4267716270.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   max_length_row.iloc[0][0]
# 543

# %%
subset[subset['length'] <= 200]
# Out:
#         id                                           sentence  length
# 0        0  [education, bachelor, ', s, degree, in, softwa...      30
# 3        3  [request, :, data, architectlocation, :, san, ...      73
# 5        5  [the, enterprise, data, infrastructure, and, a...      72
# 8        8  [data, engineer, with, kafka, (, w2, only, ), ...     165
# 9        9  [company, descriptionpb, built, is, a, residen...     176
# ...    ...                                                ...     ...
# 4508  4508  [job, title, :, datebase, adminjob, location, ...     191
# 4537  4537  [company, descriptionstarpro, -, better, data,...     184
# 4575  4575  [job, title, :, embedded, software, engineer, ...     125
# 4618  4618  [senior, embedded, developer, -, bs, degree, i...      71
# 4620  4620  [exciting, long, -, term, and, fully, remote, ...     179
#
# [466 rows x 3 columns]

# %%
subset[subset['id'] == 9].iloc[0][1]
# Out:
# C:\Users\findi\AppData\Local\Temp\ipykernel_93216\4044800302.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   subset[subset['id'] == 9].iloc[0][1]
# ['company',
#  'descriptionpb',
#  'built',
#  'is',
#  'a',
#  'residential',
#  'construction',
#  'and',
#  'developement',
#  'company',
#  'based',
#  'in',
#  'jupiter',
#  ',',
#  'fl',
#  '.',
#  'with',
#  'over',
#  '40',
#  'years',
#  'of',
#  'experience',
#  ',',
#  'pb',
#  'built',
#  'has',
#  'built',
#  'over',
#  '1',
#  'million',
#  'square',
#  'feet',
#  'of',
#  'commercial',
#  '/',
#  'retail',
#  'space',
#  'and',
#  'over',
#  '$',
#  '200',
#  'million',
#  'in',
#  'residential',
#  'custom',
#  'luxury',
#  'homes',
#  '.',
#  'they',
#  'are',
#  'known',
#  'for',
#  'constructing',
#  'unique',
#  'and',
#  'distinctive',
#  'homes',
#  'using',
#  'exquisite',
#  'materials',
#  'in',
#  'some',
#  'of',
#  'florida',
#  "'",
#  's',
#  'finest',
#  'communities',
#  '.',
#  'role',
#  'descriptionthis',
#  'is',
#  'a',
#  'full',
#  '-',
#  'time',
#  'on',
#  '-',
#  'site',
#  'role',
#  'for',
#  'a',
#  'receptionist',
#  '/',
#  'data',
#  'entry',
#  'position',
#  'at',
#  'pb',
#  'built',
#  'in',
#  'jupiter',
#  ',',
#  'fl',
#  '.',
#  'as',
#  'a',
#  'receptionist',
#  '/',
#  'data',
#  'entry',
#  ',',
#  'you',
#  'will',
#  'be',
#  'responsible',
#  'for',
#  'handling',
#  'incoming',
#  'calls',
#  ',',
#  'small',
#  'deliveries',
#  ',',
#  'disbursing',
#  'checks',
#  'and',
#  'performing',
#  'data',
#  'entry',
#  'tasks',
#  '.',
#  'you',
#  'will',
#  'also',
#  'assist',
#  'with',
#  'general',
#  'administrative',
#  'duties',
#  'and',
#  'provide',
#  'support',
#  'to',
#  'the',
#  'team',
#  'as',
#  'needed',
#  '.',
#  'qualificationsonly',
#  'locally',
#  'available',
#  'prospects',
#  'need',
#  'applyprior',
#  'experience',
#  'as',
#  'a',
#  'receptionist',
#  'or',
#  'in',
#  'a',
#  'data',
#  'entry',
#  'role',
#  'is',
#  'preferredexcellent',
#  'communication',
#  'and',
#  'interpersonal',
#  'skillsproficient',
#  'in',
#  'microsoft',
#  'office',
#  'suiteattention',
#  'to',
#  'detail',
#  'and',
#  'accuracystrong',
#  'organizational',
#  'skillsability',
#  'to',
#  'multitask',
#  'and',
#  'prioritize',
#  'responsibilities']

# %%
pip install langchain_core
# Out:
# Collecting langchain_core
#   Downloading langchain_core-0.3.51-py3-none-any.whl.metadata (5.9 kB)
# Collecting langsmith<0.4,>=0.1.125 (from langchain_core)
#   Downloading langsmith-0.3.24-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\findi\anaconda3\lib\site-packages (from langchain_core) (8.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\findi\anaconda3\lib\site-packages (from langchain_core) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\findi\anaconda3\lib\site-packages (from langchain_core) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\findi\anaconda3\lib\site-packages (from langchain_core) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\findi\anaconda3\lib\site-packages (from langchain_core) (4.11.0)
# Collecting pydantic<3.0.0,>=2.7.4 (from langchain_core)
#   Downloading pydantic-2.11.2-py3-none-any.whl.metadata (64 kB)
#      ---------------------------------------- 0.0/64.7 kB ? eta -:--:--
#      ---------------------------------------- 0.0/64.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/64.7 kB ? eta -:--:--
#      ------------------ ------------------- 30.7/64.7 kB 325.1 kB/s eta 0:00:01
#      -------------------------------------- 64.7/64.7 kB 579.8 kB/s eta 0:00:00
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\findi\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain_core) (2.1)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\findi\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (0.27.0)
# Collecting orjson<4.0.0,>=3.9.14 (from langsmith<0.4,>=0.1.125->langchain_core)
#   Downloading orjson-3.10.16-cp312-cp312-win_amd64.whl.metadata (42 kB)
#      ---------------------------------------- 0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 42.9/42.9 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2 in c:\users\findi\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (2.32.2)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\findi\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain_core) (1.0.0)
# Collecting zstandard<0.24.0,>=0.23.0 (from langsmith<0.4,>=0.1.125->langchain_core)
#   Downloading zstandard-0.23.0-cp312-cp312-win_amd64.whl.metadata (3.0 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\findi\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain_core) (0.6.0)
# Collecting pydantic-core==2.33.1 (from pydantic<3.0.0,>=2.7.4->langchain_core)
#   Downloading pydantic_core-2.33.1-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Collecting typing-extensions>=4.7 (from langchain_core)
#   Downloading typing_extensions-4.13.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3.0.0,>=2.7.4->langchain_core)
#   Downloading typing_inspection-0.4.0-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: anyio in c:\users\findi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (4.2.0)
# Requirement already satisfied: certifi in c:\users\findi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\findi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (1.0.2)
# Requirement already satisfied: idna in c:\users\findi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (3.7)
# Requirement already satisfied: sniffio in c:\users\findi\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\findi\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.125->langchain_core) (0.14.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\findi\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain_core) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\findi\anaconda3\lib\site-packages (from requests<3,>=2->langsmith<0.4,>=0.1.125->langchain_core) (2.2.2)
# Downloading langchain_core-0.3.51-py3-none-any.whl (423 kB)
#    ---------------------------------------- 0.0/423.3 kB ? eta -:--:--
#    ---------------- ----------------------- 174.1/423.3 kB 3.6 MB/s eta 0:00:01
#    ------------------------------------ --- 389.1/423.3 kB 4.1 MB/s eta 0:00:01
#    ---------------------------------------- 423.3/423.3 kB 3.3 MB/s eta 0:00:00
# Downloading langsmith-0.3.24-py3-none-any.whl (352 kB)
#    ---------------------------------------- 0.0/352.8 kB ? eta -:--:--
#    ------------------ --------------------- 163.8/352.8 kB 3.3 MB/s eta 0:00:01
#    ---------------------------------------  348.2/352.8 kB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 352.8/352.8 kB 3.1 MB/s eta 0:00:00
# Downloading pydantic-2.11.2-py3-none-any.whl (443 kB)
#    ---------------------------------------- 0.0/443.3 kB ? eta -:--:--
#    --------------- ------------------------ 174.1/443.3 kB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 419.8/443.3 kB 5.3 MB/s eta 0:00:01
#    ---------------------------------------- 443.3/443.3 kB 4.6 MB/s eta 0:00:00
# Downloading pydantic_core-2.33.1-cp312-cp312-win_amd64.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB 5.8 MB/s eta 0:00:01
#    ------------ --------------------------- 0.6/2.0 MB 6.6 MB/s eta 0:00:01
#    ----------------- ---------------------- 0.9/2.0 MB 6.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 1.1/2.0 MB 6.1 MB/s eta 0:00:01
#    ------------------------------ --------- 1.5/2.0 MB 6.3 MB/s eta 0:00:01
#    ------------------------------------- -- 1.8/2.0 MB 6.5 MB/s eta 0:00:01
#    ---------------------------------------- 2.0/2.0 MB 6.2 MB/s eta 0:00:00
# Downloading typing_extensions-4.13.1-py3-none-any.whl (45 kB)
#    ---------------------------------------- 0.0/45.7 kB ? eta -:--:--
#    ---------------------------------------- 45.7/45.7 kB ? eta 0:00:00
# Downloading orjson-3.10.16-cp312-cp312-win_amd64.whl (133 kB)
#    ---------------------------------------- 0.0/133.9 kB ? eta -:--:--
#    ---------------------------------------- 133.9/133.9 kB 7.7 MB/s eta 0:00:00
# Downloading typing_inspection-0.4.0-py3-none-any.whl (14 kB)
# Downloading zstandard-0.23.0-cp312-cp312-win_amd64.whl (495 kB)
#    ---------------------------------------- 0.0/495.6 kB ? eta -:--:--
#    ------------------------ --------------- 307.2/495.6 kB 6.3 MB/s eta 0:00:01
#    ---------------------------------------- 495.6/495.6 kB 6.2 MB/s eta 0:00:00
# Installing collected packages: zstandard, typing-extensions, orjson, typing-inspection, pydantic-core, pydantic, langsmith, langchain_core
#   Attempting uninstall: zstandard
#     Found existing installation: zstandard 0.22.0
#     Uninstalling zstandard-0.22.0:
#       Successfully uninstalled zstandard-0.22.0
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.11.0
#     Uninstalling typing_extensions-4.11.0:
#       Successfully uninstalled typing_extensions-4.11.0
#   Attempting uninstall: pydantic-core
#     Found existing installation: pydantic_core 2.14.6
#     Uninstalling pydantic_core-2.14.6:
#       Successfully uninstalled pydantic_core-2.14.6
#   Attempting uninstall: pydantic
#     Found existing installation: pydantic 2.5.3
#     Uninstalling pydantic-2.5.3:
#       Successfully uninstalled pydantic-2.5.3
# Successfully installed langchain_core-0.3.51 langsmith-0.3.24 orjson-3.10.16 pydantic-2.11.2 pydantic-core-2.33.1 typing-extensions-4.13.1 typing-inspection-0.4.0 zstandard-0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install langchain_mistralai
# Out:
# Collecting langchain_mistralai
#   Downloading langchain_mistralai-0.2.10-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.49 in c:\users\findi\anaconda3\lib\site-packages (from langchain_mistralai) (0.3.51)
# Requirement already satisfied: tokenizers<1,>=0.15.1 in c:\users\findi\anaconda3\lib\site-packages (from langchain_mistralai) (0.21.1)
# Requirement already satisfied: httpx<1,>=0.25.2 in c:\users\findi\anaconda3\lib\site-packages (from langchain_mistralai) (0.27.0)
# Collecting httpx-sse<1,>=0.3.1 (from langchain_mistralai)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Requirement already satisfied: pydantic<3,>=2 in c:\users\findi\anaconda3\lib\site-packages (from langchain_mistralai) (2.11.2)
# Requirement already satisfied: anyio in c:\users\findi\anaconda3\lib\site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (4.2.0)
# Requirement already satisfied: certifi in c:\users\findi\anaconda3\lib\site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\findi\anaconda3\lib\site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (1.0.2)
# Requirement already satisfied: idna in c:\users\findi\anaconda3\lib\site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (3.7)
# Requirement already satisfied: sniffio in c:\users\findi\anaconda3\lib\site-packages (from httpx<1,>=0.25.2->langchain_mistralai) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\findi\anaconda3\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.2->langchain_mistralai) (0.14.0)
# Requirement already satisfied: langsmith<0.4,>=0.1.125 in c:\users\findi\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain_mistralai) (0.3.24)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\findi\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain_mistralai) (8.2.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\findi\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain_mistralai) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\findi\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain_mistralai) (6.0.1)
# Requirement already satisfied: packaging<25,>=23.2 in c:\users\findi\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain_mistralai) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\findi\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.49->langchain_mistralai) (4.13.1)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\findi\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain_mistralai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.33.1 in c:\users\findi\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain_mistralai) (2.33.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\users\findi\anaconda3\lib\site-packages (from pydantic<3,>=2->langchain_mistralai) (0.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in c:\users\findi\anaconda3\lib\site-packages (from tokenizers<1,>=0.15.1->langchain_mistralai) (0.30.1)
# Requirement already satisfied: filelock in c:\users\findi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\findi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (2024.3.1)
# Requirement already satisfied: requests in c:\users\findi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (2.32.2)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\findi\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (4.66.4)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\findi\anaconda3\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.49->langchain_mistralai) (2.1)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in c:\users\findi\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain_mistralai) (3.10.16)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in c:\users\findi\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain_mistralai) (1.0.0)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in c:\users\findi\anaconda3\lib\site-packages (from langsmith<0.4,>=0.1.125->langchain-core<1.0.0,>=0.3.49->langchain_mistralai) (0.23.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\findi\anaconda3\lib\site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\findi\anaconda3\lib\site-packages (from requests->huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (2.2.2)
# Requirement already satisfied: colorama in c:\users\findi\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0,>=0.16.4->tokenizers<1,>=0.15.1->langchain_mistralai) (0.4.6)
# Downloading langchain_mistralai-0.2.10-py3-none-any.whl (16 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Installing collected packages: httpx-sse, langchain_mistralai
# Successfully installed httpx-sse-0.4.0 langchain_mistralai-0.2.10
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# import os
# from langchain_mistralai import ChatMistralAI
# from langchain_core.prompts import PromptTemplate
#
# def set_api_key_from_file(file_path):
#     try:
#         with open(file_path, 'r') as file:
#             api_key = file.read().strip()
#             print(api_key)
#             os.environ["MISTRAL_API_KEY"] = api_key
#             print("Mistral API Key set successfully.")
#     except FileNotFoundError:
#         raise FileNotFoundError(f"Error: File '{file_path}' not found.")
#     except Exception as e:
#         raise Exception(f"An error occurred: {e}")
#
# # Set API key using the file
# api_key_path = "mistral_key.txt"
# set_api_key_from_file(api_key_path)
#
# # Initialize MistralAI with LangChain
# llm = ChatMistralAI(model_name="mistral-small", temperature=0.7)
#
# # Read the prompt template from the file
# with open("prompt.txt") as f:
#     template = f.read()
#
# # Define the prompt using LangChain
# prompt_template = PromptTemplate.from_template(template)

# %%
from tqdm import tqdm

# Take the first 50 rows of the DataFrame
subset50 = subset[:50]


result = []
for job_description in tqdm(subset50['sentence'], desc="Processing job descriptions"):
    formatted_prompt = prompt_template.format(job_description=job_description)
    response = llm.invoke(formatted_prompt)
    result.append(response.content)
# Out:
# Processing job descriptions: 100%|██████████| 50/50 [18:38<00:00, 22.38s/it]

# %%
subset50['result']=result
# Out:
# C:\Users\findi\AppData\Local\Temp\ipykernel_93216\820044623.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset50['result']=result

# %%
subset50.to_csv('subset_50.csv')

# %%
import os
from langchain_mistralai import ChatMistralAI
from langchain_core.prompts import PromptTemplate

def set_api_key_from_file(file_path):
    try:
        with open(file_path, 'r') as file:
            api_key = file.read().strip()
            print(api_key)
            os.environ["MISTRAL_API_KEY"] = api_key
            print("Mistral API Key set successfully.")
    except FileNotFoundError:
        raise FileNotFoundError(f"Error: File '{file_path}' not found.")
    except Exception as e:
        raise Exception(f"An error occurred: {e}")

# Set API key using the file
api_key_path = "mistral_key.txt"
set_api_key_from_file(api_key_path)

# Initialize MistralAI with LangChain
llm = ChatMistralAI(model_name="mistral-large-latest", temperature=0.7)

# Read the prompt template from the file
with open("prompt.txt") as f:
    template = f.read()

# Define the prompt using LangChain
prompt_template = PromptTemplate.from_template(template)
# Out:
# gtLWnZWKyHGeQr69A4Gi5v7CoNjpxukp
# Mistral API Key set successfully.

# %%
import os
import requests
import json

def set_api_key_from_file(file_path):
    try:
        with open(file_path, 'r') as file:
            api_key = file.read().strip()
            os.environ["MISTRAL_API_KEY"] = api_key
            print("Mistral API Key set successfully.")
    except FileNotFoundError:
        raise FileNotFoundError(f"Error: File '{file_path}' not found.")
    except Exception as e:
        raise Exception(f"An error occurred: {e}")

# Set API key
api_key_path = "mistral_key.txt"
set_api_key_from_file(api_key_path)

# Load prompt template from file
with open("prompt.txt", "r") as f:
    template = f.read()

# Direct call to Mistral API
def get_mistral_response(user_input, model="mistral-large-latest", temperature=0.7):
    api_key = os.environ["MISTRAL_API_KEY"]
    url = "https://api.mistral.ai/v1/chat/completions"
    headers = {
        "Authorization": f"Bearer {api_key}",
        "Content-Type": "application/json"
    }

    # Format the prompt
    prompt = template.format(job_description=user_input)

    payload = {
        "model": model,
        "temperature": temperature,
        "messages": [
            {"role": "user", "content": prompt}
        ]
    }

    response = requests.post(url, headers=headers, data=json.dumps(payload))

    if response.status_code == 200:
        return response.json()["choices"][0]["message"]["content"]
    else:
        raise Exception(f"Error: {response.status_code} - {response.text}")
# Out:
# Mistral API Key set successfully.

# %%
from tqdm import tqdm
import pandas as pd

# Take the first 25 rows of the DataFrame
subset50_large = subset[:25].copy()  # .copy() avoids SettingWithCopyWarning

result = []

# Loop with progress bar
for job_description in tqdm(subset50_large['sentence'], desc="Processing job descriptions"):
    try:
        response = get_mistral_response(job_description)  # from the earlier function
        result.append(response)
    except Exception as e:
        print(f"❌ Error: {e}")
        result.append("ERROR")

# Assign results to a new column
subset50_large['result'] = result
# Out:
# Processing job descriptions: 100%|██████████| 25/25 [21:58<00:00, 52.73s/it]

# %%
subset50_large['result']=result
subset50_large.to_csv('subset_50_large.csv')
